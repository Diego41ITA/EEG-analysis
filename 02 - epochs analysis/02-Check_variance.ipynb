# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib

# %% [markdown]
# This is an easy script to visually check the variance of the signals

# %%
#matplotlib.use('Qt5Agg')

# %%
#reading the dataset of ERP divided by subject and by type of stimulus
data_n=pd.read_csv('ERP_SUB_VARIANCE',header=None)
data_n.head(70)

# %%
#plotting the data
sns.lineplot(data=data_n, x=data_n.columns[2], y=data_n.columns[1],hue=data_n.columns[0])
# Out:
# <AxesSubplot:xlabel='2', ylabel='1'>
